# %% [markdown]
# <a href="https://colab.research.google.com/github/Jtorosuaza/PG4/blob/main/EnergiaSolar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PROYECTO**

# %% [markdown]
# **Identificar problema**

# %% [markdown]
# **Cargar los Datos**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('DATOS_SENSORES_AMBIENTALES_ARBOLES_SOLARES-MUNICIPIO_IBAGUE_20240928.csv')
data
# Out:
#       Zona / Corregimiento            Fecha  Temperatura (°)  Polución (ICA)  \
# 0           Villa Restrepo  9/01/2023 18:53               21           50.70
# 1           Villa Restrepo  9/01/2023 18:53               21           50.70
# 2           Villa Restrepo  9/01/2023 18:53               21           50.70
# 3           Villa Restrepo  9/01/2023 18:53               21           50.70
# 4           Villa Restrepo  9/01/2023 18:53               21           50.70
# ...                    ...              ...              ...             ...
# 83321               Juntas  28/02/2023 7:52               25           10.29
# 83322               Juntas  28/02/2023 7:53               25           12.15
# 83323               Juntas  28/02/2023 7:54               25           11.97
# 83324               Juntas  28/02/2023 7:55               25           12.41
# 83325               Juntas  28/02/2023 7:56               25           12.59
#
# ...

# %% [markdown]
# **Exploración de Datos del Dataframe (identificación de tipos de datos)**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83326 entries, 0 to 83325
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Zona / Corregimiento  83326 non-null  object
#  1   Fecha                 83326 non-null  object
#  2   Temperatura (°)       83326 non-null  int64
#  3   Polución (ICA)        83326 non-null  float64
#  4   Humedad (%)           83326 non-null  int64
#  5   Ruido (dB)            83326 non-null  int64
#  6   CO2 (PPM)             83326 non-null  int64
#  7   NO2 (PPM)             83326 non-null  float64
#  8   Watts (Vatio)         83326 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 5.7+ MB

# %% [markdown]
# **Generación de Estadísticas Descriptivas**

# %%
data.describe()

# %% [markdown]
# **Visualización de datos utilizando gráficos de barras, histogramas y gráficos de dispersión**

# %%
sns.pairplot(data)

# %% [markdown]
# **Identificación y manejo de valores atípicos y tendencias en los datos**

# %%
data.isnull().sum()
# Out:
# Zona / Corregimiento    0
# Fecha                   0
# Temperatura (°)         0
# Polución (ICA)          0
# Humedad (%)             0
# Ruido (dB)              0
# CO2 (PPM)               0
# NO2 (PPM)               0
# Watts (Vatio)           0
# dtype: int64

# %%
data[''] = pd.to_numeric(data[''], errors='coerce')

# %% [markdown]
# **Uso de técnicas como imputación de la media, mediana y regresión para completar datos faltantes**

# %%
data[''].fillna(data[''].median(), inplace=True)

# %% [markdown]
# **Eliminación de registros con datos faltantes o imputación de valores categóricos**

# %%
data.replace(['error','Null','null', ' '], np.nan, inplace=True)

# %% [markdown]
# **Aplicación de técnicas de One-hot encoding, Label encoding, y Ordinal encoding**

# %% [markdown]
# **Cálculo y visualización de matrices de correlación.**

# %% [markdown]
# **Aplicación de PCA para reducir la dimensionalidad de datasets**

# %%
dataBD = pd.read_excel('BD_DIB_Outdoor_Solar_Panels_Electrical_Parameters.xlsx')
dataBD
# Out:
#        Panel       C            datetime  Irradiance  Tpanel  Tamb        Voc  \
# 0       CIGS  0.0148 2021-03-08 16:16:00         169      27    25  35.720841
# 1       CIGS  0.0148 2021-03-08 16:43:00          88      26    25  33.959140
# 2       CIGS  0.0148 2021-03-08 16:50:00          78      26    25  33.623958
# 3       CIGS  0.0148 2021-03-08 16:58:00          61      25    24  32.919676
# 4       CIGS  0.0148 2021-03-08 17:00:00          63      25    24  33.095248
# ...      ...     ...                 ...         ...     ...   ...        ...
# 301967   HIT  0.0032 2021-12-29 16:26:00         105      24    21  64.510372
# 301968   HIT  0.0032 2021-12-29 16:27:00          98      24    21  64.328974
# 301969   HIT  0.0032 2021-12-29 16:35:00          68      23    21  63.354691
# 301970   HIT  0.0032 2021-12-29 16:36:00          63      23    21  63.146962
# 301971   HIT  0.0032 2021-12-29 16:38:00          55      22    21  62.784166
#
# ...

# %%
dataSantaMarta = pd.read_csv('SA7D2B1.csv')
dataSantaMarta
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-f01b6be6a140> in <cell line: 1>()
# ----> 1 dataSantaMarta = pd.read_csv('SA7D2B1.csv')
#       2 dataSantaMarta
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
dataA01 = pd.read_csv('Datos_Atmos_01_2018.csv', sep=';')
dataA01
# Out:
#       Información Sensor Boxes #  Unnamed: 1           Unnamed: 2  \
# 0        Universidad de Antioquia        NaN                  NaN
# 1               02/14/18 15:13:14        NaN                  NaN
# 2                             NaN        NaN                  NaN
# 3                           Fecha       Hora  Panel_temperature_1
# 4                        01/01/18   05:09:55                   16
# ...                           ...        ...                  ...
# 13033                    31/01/18   18:44:48                   23
# 13034                    31/01/18   18:45:48                   23
# 13035                    31/01/18   20:09:46                   21
# 13036                    31/01/18   21:30:45                   21
# 13037                    31/01/18   22:50:47                   19
#
#                 Unnamed: 3             Unnamed: 4             Unnamed: 5  \
# 0                      NaN                    NaN                    NaN
# ...

# %%
dataA01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13038 entries, 0 to 13037
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Información Sensor Boxes #   13037 non-null  object
#  1   Unnamed: 1                   13035 non-null  object
#  2   Unnamed: 2                   13035 non-null  object
#  3   Unnamed: 3                   13035 non-null  object
#  4   Unnamed: 4                   13035 non-null  object
#  5   Unnamed: 5                   13035 non-null  object
#  6   Unnamed: 6                   13035 non-null  object
#  7   Unnamed: 7                   13035 non-null  object
# dtypes: object(8)
# memory usage: 815.0+ KB

# %%
dataPSM = pd.read_excel('PSM17_I-V_data.xls')
dataPSM
# Out:
#                                    File                 Date  Efficiency(%)  \
# 0      Mini_Mod_1_18.01.26_11.49.06.csv  2018-01-26 11:49:06      13.562386
# 1      Mini_Mod_1_18.01.26_11.50.05.csv  2018-01-26 11:50:05      21.118133
# 2      Mini_Mod_1_18.01.26_11.51.06.csv  2018-01-26 11:51:06      21.594225
# 3      Mini_Mod_1_18.01.26_11.52.06.csv  2018-01-26 11:52:06      22.214476
# 4      Mini_Mod_1_18.01.26_11.53.05.csv  2018-01-26 11:53:05      22.343724
# ...                                 ...                  ...            ...
# 13155  Mini_Mod_1_18.02.16_08.10.05.csv  2018-02-16 08:10:05      21.782713
# 13156  Mini_Mod_1_18.02.16_08.11.06.csv  2018-02-16 08:11:06      42.265869
# 13157  Mini_Mod_1_18.02.16_08.12.06.csv  2018-02-16 08:12:06      27.251965
# 13158  Mini_Mod_1_18.02.16_08.13.05.csv  2018-02-16 08:13:05      21.131700
# 13159  Mini_Mod_1_18.02.16_08.14.06.csv  2018-02-16 08:14:06      37.353739
#
# ...
